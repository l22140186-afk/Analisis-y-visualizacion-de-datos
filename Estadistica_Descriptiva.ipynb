# %% [markdown]
# <a href="https://colab.research.google.com/github/l22140186-afk/Analisis-y-visualizacion-de-datos/blob/main/Estadistica_Descriptiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

datos=pd.read_excel("data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1024166350.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 datos=pd.read_excel("data.xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
print(datos.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2454483301.py in <cell line: 0>()
# ----> 1 print(datos.head())
#
# NameError: name 'datos' is not defined

# %%
mean(datos$Estatura)
# Out:
#   File "/tmp/ipython-input-3239933943.py", line 1
#     mean(datos$Estatura)
#               ^
# SyntaxError: invalid syntax

# %%
install.packages("readxl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2631157262.py in <cell line: 0>()
# ----> 1 install.packages("readxl")
#
# NameError: name 'install' is not defined

# %%
# !apt-get install -y r-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.5.2-1.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("readxl")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/readxl_1.4.5.tar.gz'
# Content type 'application/x-gzip' length 1636512 bytes (1.6 MB)
# ...
# downloaded 1.6 MB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpRqST9s/downloaded_packages’

# %%
# %%R
# list.files("/content")
# Out:
# [1] "drive"       "sample_data"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%R
# list.files("/content/drive/MyDrive")
# Out:
#   [1] "0-443929390787446_copia.pdf"
#   [2] "17702265663737427410509763500873.jpg"
#   [3] "17702493551835889937960584769117.jpg"
#   [4] "17702493828515629308881058032922.jpg"
#   [5] "a5.jpeg"
#   [6] "ADMINISTRACION DE ALMACENES.gslides"
#   [7] "ADMINISTRACION DE ALMACENES.pptx.pdf"
#   [8] "ADMINISTRACION DE INVENTARIOS.gslides"
#   [9] "Alondra Bressant Olvera  .pdf"
#  [10] "Alta medica .gdoc"
#  [11] "Alta medica .pdf"
#  [12] "Ana Daniela Barron Toledo  (1).pdf"
#  [13] "Ana Daniela Barron Toledo  (2).pdf"
#  [14] "Ana Daniela Barron Toledo .gdoc"
#  [15] "Ana Daniela Barron Toledo .pdf"
#  [16] "Ana Daniela Barron Toledo 1 (1).pdf"
#  [17] "Ana Daniela Barron Toledo 1 (2).pdf"
#  [18] "Ana Daniela Barron Toledo 1.gdoc"
#  [19] "Ana Daniela Barron Toledo 1.pdf"
#  [20] "Ana Daniela Barron Toledo 10k 1:07:00 minutos "
#  [21] "Ana Daniela Barron Toledo examen .pdf"
#  [22] "Ana Daniela Barron Toledo habil.gdoc"
#  [23] "Ana Daniela Barron Toledo habil.pdf"
# ...

# %%
# %%R
# list.files("/content/drive/MyDrive/analisis")
# Out:
# [1] "base_datos_helados_500_registros.xlsx"

# %%
# %%R
# library(readxl)
#
# datos <- read_excel("/content/drive/MyDrive/analisis/base_datos_helados_500_registros.xlsx")
# head(datos)
# Out:
# # A tibble: 6 × 6
#   Helado   Estatura  peso Ingresos Educacion Hijos
#   <chr>       <dbl> <dbl>    <dbl>     <dbl> <dbl>
# 1 Limón        1.81  90.0    1602.         4     1
# 2 Maracuyá     1.85  85.2    1740.         2     0
# 3 Mora         1.64  71.5    1432.         1     4
# 4 Coco         1.56  86.2    2068.         1     2
# 5 Fresa        1.85  59.9    1639.         1     0
# 6 Mora         1.65  86.4    2026.         2     2

# %%
# %%R
# mean(datos$Estatura)
# Out:
# [1] 1.734004

# %%
# %%R
# apply(as.matrix(datos[,2:4]), 2, mean)
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
# %%R
# lapply(datos[,2:4], mean)
# Out:
# $Estatura
# [1] 1.734004
#
# $peso
# [1] 74.48267
#
# $Ingresos
# [1] 1700.417

# %%
# %%R
# unlist(lapply(datos[,2:4], mean))
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
# %%R
# median(datos$Estatura)
# Out:
# [1] 1.739476

# %%
# %%R
# apply(as.matrix(datos[,2:4]), 2, median)
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
# %%R
# unlist(lapply(datos[,2:4], median))
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
# %%R
# var(datos$Estatura)
# Out:
# [1] 0.01016447

# %%
# %%R
# sd(datos$peso)
# Out:
# [1] 11.62325

# %%
# %%R
# apply(as.matrix(datos[,2:4]), 2, sd)
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
# %%R
# apply(as.matrix(datos[,2:4]), 2, sd)
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
# %%R
# quantile(datos$Estatura)
# Out:
#       0%      25%      50%      75%     100%
# 1.550751 1.648060 1.739476 1.822418 1.899272

# %%
# %%R
# quantile(datos$Estatura, probs = 0.25)
# Out:
#     25%
# 1.64806

# %%
# %%R
# quantile(datos$Estatura, probs = c(0.25, 0.75))
# Out:
#      25%      75%
# 1.648060 1.822418

# %%
# %%R
# quantile(datos$Estatura, probs = 0.20)
# Out:
#      20%
# 1.630622

# %%
# %%R
# quantile(datos$Estatura, probs = c(0.10, 0.15, 0.20))
# Out:
#      10%      15%      20%
# 1.593158 1.610960 1.630622

# %%
# %%R
# summary(datos)
# Out:
#     Helado             Estatura          peso          Ingresos
#  Length:500         Min.   :1.551   Min.   :55.08   Min.   :1202
#  Class :character   1st Qu.:1.648   1st Qu.:64.11   1st Qu.:1449
#  Mode  :character   Median :1.739   Median :74.41   Median :1714
#                     Mean   :1.734   Mean   :74.48   Mean   :1700
#                     3rd Qu.:1.822   3rd Qu.:84.46   3rd Qu.:1955
#                     Max.   :1.899   Max.   :94.93   Max.   :2199
#    Educacion        Hijos
#  Min.   :1.00   Min.   :0.000
#  1st Qu.:2.00   1st Qu.:1.000
#  Median :3.00   Median :2.000
#  Mean   :2.58   Mean   :2.088
#  3rd Qu.:4.00   3rd Qu.:3.000
#  Max.   :4.00   Max.   :4.000

# %%
# %%R
# datos$Helado = as.factor(datos$Helado)
# summary(datos)
# Out:
#        Helado      Estatura          peso          Ingresos      Educacion
#  Chocolate:73   Min.   :1.551   Min.   :55.08   Min.   :1202   Min.   :1.00
#  Coco     :74   1st Qu.:1.648   1st Qu.:64.11   1st Qu.:1449   1st Qu.:2.00
#  Fresa    :69   Median :1.739   Median :74.41   Median :1714   Median :3.00
#  Limón    :84   Mean   :1.734   Mean   :74.48   Mean   :1700   Mean   :2.58
#  Maracuyá :59   3rd Qu.:1.822   3rd Qu.:84.46   3rd Qu.:1955   3rd Qu.:4.00
#  Mora     :59   Max.   :1.899   Max.   :94.93   Max.   :2199   Max.   :4.00
#  Vainilla :82
#      Hijos
#  Min.   :0.000
#  1st Qu.:1.000
#  Median :2.000
#  Mean   :2.088
#  3rd Qu.:3.000
#  Max.   :4.000

# %% [markdown]
# #conclusiones

# %% [markdown]
# Se calcularon medidas de tendencia central como media y mediana.
#
# Se analizaron medidas de dispersión como varianza y desviación estándar.
#
# Se interpretaron los cuartiles y percentiles.
#
# Se identificó el comportamiento general de las variables
